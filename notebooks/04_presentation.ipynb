# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.feature_engineering import select_features
from src.data_preprocessing import preprocess_data
from src.modeling import train_and_evaluate_models

# %% [markdown]
# ## 📥 Carregando os dados e pipeline

# %%
features = select_features()
X_train, X_test, y_train, y_test = preprocess_data("../data/raw/train.csv", features, "SalePrice")

# %% [markdown]
# ## 🤖 Treinamento e Avaliação

# %%
results = train_and_evaluate_models(X_train, y_train)

# %% [markdown]
# ## 📈 Visualização das Métricas

# %%
models, rmses, r2s = zip(*results)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.bar(models, rmses, color='skyblue')
plt.title('RMSE por Modelo')
plt.ylabel('RMSE')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
plt.bar(models, r2s, color='lightgreen')
plt.title('R² por Modelo')
plt.ylabel('R²')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📌 Conclusões
# ### - Modelos lineares se saíram bem, mas Random Forest teve melhor performance geral.
# ### - Features selecionadas mostraram boa capacidade preditiva.
# ### - Possível evoluir com mais engenharia de variáveis e validação cruzada.
#
# ### Obrigado!
